# %% [markdown]
# # Pandas
# Its most famous lib used to read data and process data.<br>
# Data comes in rows and cols format called as Data Frames

# %% [markdown]
# Weather DataSet

# %% [markdown]
# Questions?
#
#
# 1. What was the maximum temperature in month of Jan?
# 2. On which days did it rain?
# 3. What was the average speed of wind duting the month?

# %%
import pandas as pd

# %%
df = pd.read_csv('nyc_weather.csv');

# %%
#head or tail returns firs or last 5 rows
df.head()
# Out:
#         EST  Temperature  DewPoint  ...  CloudCover  Events  WindDirDegrees
# 0  1/1/2016           38        23  ...           5     NaN             281
# 1  1/2/2016           36        18  ...           3     NaN             275
# 2  1/3/2016           40        21  ...           1     NaN             277
# 3  1/4/2016           25         9  ...           3     NaN             345
# 4  1/5/2016           20        -3  ...           0     NaN             333
#
# [5 rows x 11 columns]

# %%
#to get Max val of col
df['Temperature'].max()
# Out:
# 50

# %%
# To pick rows based on conditions

df[['Temperature','EST']][df['Events'] == 'Rain']
# Out:
#     Temperature        EST
# 8            44   1/9/2016
# 9            50  1/10/2016
# 15           47  1/16/2016
# 26           41  1/27/2016

# %%
df[df['Events'] == 'Rain']
# Out:
#           EST  Temperature  DewPoint  ...  CloudCover  Events  WindDirDegrees
# 8    1/9/2016           44        38  ...           8    Rain              76
# 9   1/10/2016           50        46  ...           7    Rain             109
# 15  1/16/2016           47        37  ...           7    Rain             340
# 26  1/27/2016           41        22  ...           3    Rain             311
#
# [4 rows x 11 columns]

# %%
df['WindSpeedMPH'].mean()
# Out:
# 6.892857142857143

# %%
df = pd.read_csv('weather_data.csv');

# %%
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %%
#6 rows 4 cols
df.shape
# Out:
# (6, 4)

# %% [markdown]
# ### Slicing

# %%
df[2:5]
# Out:
#         day  temperature  windspeed event
# 2  1/3/2017           28          2  Snow
# 3  1/4/2017           24          7  Snow
# 4  1/5/2017           32          4  Rain

# %%
df.day
#or df['day'] or df.get('day')
# Out:
# 0    1/1/2017
# 1    1/2/2017
# 2    1/3/2017
# 3    1/4/2017
# 4    1/5/2017
# 5    1/6/2017
# Name: day, dtype: object

# %% [markdown]
# #### To select multiple cols

# %%
df[['day','temperature']]
# Out:
#         day  temperature
# 0  1/1/2017           32
# 1  1/2/2017           35
# 2  1/3/2017           28
# 3  1/4/2017           24
# 4  1/5/2017           32
# 5  1/6/2017           31

# %%
df['temperature'].max()
# Out:
# 35

# %% [markdown]
# ### describe()

# %%
df['temperature'].describe()
# Out:
# count     6.000000
# mean     30.333333
# std       3.829708
# min      24.000000
# 25%      28.750000
# 50%      31.500000
# 75%      32.000000
# max      35.000000
# Name: temperature, dtype: float64

# %%
df[df['temperature']==df['temperature'].max()]
# Out:
#         day  temperature  windspeed  event
# 1  1/2/2017           35          7  Sunny

# %%
df['day'][df['temperature']==df['temperature'].max()]
# Out:
# 1    1/2/2017
# Name: day, dtype: object

# %% [markdown]
# ![Screenshot_2021-07-14_21-19-57.png](data:image/png;base64,...)
